# %% [markdown]
# # Airbnb Recommendation System

# %%
# All required imports
import numpy as np
import pandas as pd

# %%
listings = pd.read_csv('listings.csv')
listings
# Out:
#              id                            listing_url  \
# 0          1419      https://www.airbnb.com/rooms/1419
# 1          8077      https://www.airbnb.com/rooms/8077
# 2         12604     https://www.airbnb.com/rooms/12604
# 3         23691     https://www.airbnb.com/rooms/23691
# 4         26654     https://www.airbnb.com/rooms/26654
# ...         ...                                    ...
# 19338  45348297  https://www.airbnb.com/rooms/45348297
# 19339  45351124  https://www.airbnb.com/rooms/45351124
# 19340  45351175  https://www.airbnb.com/rooms/45351175
# 19341  45351235  https://www.airbnb.com/rooms/45351235
# 19342  45351322  https://www.airbnb.com/rooms/45351322
#
#                                                     name  \
# 0                        Beautiful home in amazing area!
# 1                     Downtown Harbourfront Private Room
# 2                         Seaton Village Parlour Bedroom
# 3                        Queen Bedroom close to downtown
# ...

# %% [markdown]
# ## Data preprocessing and cleaning

# %%
#Changing host verification to binary
listings.host_identity_verified[listings.host_identity_verified == 't'] = 1
listings.host_identity_verified[listings.host_identity_verified == 'f'] = 0

#Changing instant bookable to binary
listings.instant_bookable[listings.instant_bookable == 't'] = 1
listings.instant_bookable[listings.instant_bookable == 'f'] = 0
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_16404/2932569260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings.host_identity_verified[listings.host_identity_verified == 't'] = 1
# C:\Users\User\AppData\Local\Temp/ipykernel_16404/2932569260.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings.host_identity_verified[listings.host_identity_verified == 'f'] = 0
# C:\Users\User\AppData\Local\Temp/ipykernel_16404/2932569260.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#We do not want listings that have not yet been reviewed, so they are removed
listings = listings[listings.number_of_reviews != 0]


#Dropping listings which has no name,hostname,description of bathrooms and no total review score
listings = listings[listings.name.notna()]
listings = listings[listings.host_name.notna()]
listings = listings[listings.bathrooms_text.notna()]
listings = listings[listings.review_scores_rating.notna()]

#Now checking number of null values
listings.isnull().sum()
# Out:
# id                              0
# listing_url                     0
# name                            0
# description                   291
# neighborhood_overview        4542
# host_id                         0
# host_name                       0
# host_response_rate           5212
# host_acceptance_rate         3372
# host_identity_verified          0
# neighbourhood_cleansed          0
# property_type                   0
# bathrooms_text                  0
# bedrooms                     1096
# number_of_reviews               0
# review_scores_rating            0
# review_scores_cleanliness      34
# review_scores_checkin          36
# review_scores_value            38
# instant_bookable                0
# dtype: int64

# %%
for index, row in listings.iterrows():
    if(row['review_scores_cleanliness'].isnull()):
        print(index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16404/604813972.py in <module>
#       1 for index, row in listings.iterrows():
# ----> 2     if(row['review_scores_cleanliness'].isnull()):
#       3         print(index)
#
# AttributeError: 'float' object has no attribute 'isnull'
